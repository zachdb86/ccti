# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/zbresnick/Downloads/demo-inquiries (2).csv')

# %%
data
# Out:
#                        email (S)  \
# 0           rkcudjoe@hookops.com
# 1    luca.rimoldi@9024sports.com
# 2    bhavika.rambhai@tnz.govt.nz
# 3                 gabriel@gdr.pr
# 4      chinyi.chow@meltwater.com
# 5            keith@ayzenberg.com
# 6             belmoroe@gmail.com
# 7                  skim@mapr.com
# 8          dsuarez@ayzenberg.com
# 9   brandonreynolds1@hotmail.com
# 10               brandon@grin.co
# 11         thomas@edgeskills.com
# 12           kim.harris@8451.com
#
#                                   requested_apis (SS)     requested_at (S)  \
# 0                           { "Sentiment Analyzer" }   2018-01-18 17:49:10
# 1   { "Baseline EMV", "Bot Detector", "Enhanced Pe...  2018-01-18 11:57:10
# 2   { "Baseline EMV", "Bot Detection", "Knowledge ...  2018-01-18 00:19:09
# 3   { "Baseline EMV", "Enhanced Personality Evalua...  2018-01-30 07:47:09
# 4   { "Baseline EMV", "Bot Detector", "Enhanced Pe...  2018-01-24 01:18:11
# ...

# %%
data2 = data.drop('visable (S)', axis=1)

# %%
data2.columns = ['email', 'requested_apis', 'requested_at', 'approved_apis', 'company', 'message', 'name']

# %%
data2
# Out:
#                            email  \
# 0           rkcudjoe@hookops.com
# 1    luca.rimoldi@9024sports.com
# 2    bhavika.rambhai@tnz.govt.nz
# 3                 gabriel@gdr.pr
# 4      chinyi.chow@meltwater.com
# 5            keith@ayzenberg.com
# 6             belmoroe@gmail.com
# 7                  skim@mapr.com
# 8          dsuarez@ayzenberg.com
# 9   brandonreynolds1@hotmail.com
# 10               brandon@grin.co
# 11         thomas@edgeskills.com
# 12           kim.harris@8451.com
#
#                                        requested_apis         requested_at  \
# 0                           { "Sentiment Analyzer" }   2018-01-18 17:49:10
# 1   { "Baseline EMV", "Bot Detector", "Enhanced Pe...  2018-01-18 11:57:10
# 2   { "Baseline EMV", "Bot Detection", "Knowledge ...  2018-01-18 00:19:09
# 3   { "Baseline EMV", "Enhanced Personality Evalua...  2018-01-30 07:47:09
# 4   { "Baseline EMV", "Bot Detector", "Enhanced Pe...  2018-01-24 01:18:11
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://dbadmin:islandOTHERearth3!!@admin-portal.caytoicecby5.us-west-2.rds.amazonaws.com/admin_portal_prod')

# %%
data2.to_sql('demo_inquiries', engine, index=False, if_exists='append')
